# %% [markdown]
# Q1. Load the given retail sales dataset into a Pandas DataFrame and display the first 5 rows along with the dataset information to understand its structure.

# %%
# Load the dataset (using the exact uploaded filename)
df = pd.read_csv('retail_dataset .csv')

# Display the first 5 rows
print("First 5 rows of the dataset:")
display(df.head())

# Display dataset information
print("\nDataset Information:")
df.info()
# Out:
# First 5 rows of the dataset:
#   Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0           T001        C015            Books       7.0   167.0  02-02-2023
# 1           T002        C004             Toys       4.0   374.0  17-02-2023
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024
# 4           T005        C022            Books       7.0   282.0  27-07-2024
#
#   Region
# 0  North
# 1  South
# 2  South
# 3  South
# 4   West
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    100 non-null    object
#  1   Customer ID       100 non-null    object
#  2   Product Category  97 non-null     object
#  3   Quantity          98 non-null     float64
# ...

# %% [markdown]
# Q2. Inspect the dataset and identify missing values in each column. Display the total number of missing values present in the dataset.

# %%
# Identify missing values in each column
missing_per_column = df.isnull().sum()
print("Missing values in each column:")
print(missing_per_column)

# Total number of missing values
total_missing = df.isnull().sum().sum()
print(f"\nTotal number of missing values in the dataset: {total_missing}")
# Out:
# Missing values in each column:
# Transaction ID      0
# Customer ID         0
# Product Category    3
# Quantity            2
# Price               5
# Date                0
# Region              2
# dtype: int64
#
# Total number of missing values in the dataset: 12

# %% [markdown]
# Q3. Replace missing values in the Quantity and Price columns with their respective mean values using Pandas.

# %%
# Replace missing values with the mean of the column
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].mean())
df['Price'] = df['Price'].fillna(df['Price'].mean())

print("Missing values in 'Quantity' and 'Price' have been replaced with their means.")
# Out:
# Missing values in 'Quantity' and 'Price' have been replaced with their means.

# %% [markdown]
# Q4. Remove all rows where the Product Category or Region column contains missing values.

# %%
# Drop rows with NaN in specific columns
df = df.dropna(subset=['Product Category', 'Region'])

print("Rows with missing 'Product Category' or 'Region' have been removed.")

# %% [markdown]
# Q5. Create a new column called Revenue using NumPy, where: Revenue = Quantity × Price. Display the updated dataset with the new column.

# %%
# Create the Revenue column using NumPy
df['Revenue'] = np.multiply(df['Quantity'], df['Price'])

# Display the updated dataset
print("Updated dataset with 'Revenue' column:")
display(df.head())
# Out:
# Updated dataset with 'Revenue' column:
#   Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0           T001        C015            Books       7.0   167.0  02-02-2023
# 1           T002        C004             Toys       4.0   374.0  17-02-2023
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024
# 4           T005        C022            Books       7.0   282.0  27-07-2024
#
#   Region  Revenue
# 0  North   1169.0
# 1  South   1496.0
# 2  South   8472.0
# 3  South   1520.0
# 4   West   1974.0

# %% [markdown]
# Q6. Using NumPy, calculate the total revenue generated from all transactions in the dataset.

# %%
# Calculate total revenue
total_revenue = np.sum(df['Revenue'])

print(f"Total Revenue Generated: ${total_revenue:.2f}")

# %% [markdown]
# Q7. Group the dataset by Product Category and calculate the total revenue generated by each category.

# %%
# Group by Product Category and sum the revenue
category_revenue = df.groupby('Product Category')['Revenue'].sum()

print("Total Revenue by Product Category:")
print(category_revenue)

# %% [markdown]
# Q8. Based on the revenue calculated for each product category, identify the top 3 categories with the highest revenue and the bottom 3 categories with the lowest revenue.

# %%
# Identify top 3 categories
top_3_categories = category_revenue.nlargest(3)

# Identify bottom 3 categories
bottom_3_categories = category_revenue.nsmallest(3)

print("Top 3 Categories with Highest Revenue:")
print(top_3_categories)

print("\nBottom 3 Categories with Lowest Revenue:")
print(bottom_3_categories)

# %% [markdown]
# Q9. Group the dataset by Region and calculate the total revenue generated in each region. Identify the region with the highest revenue and the region with the lowest revenue.

# %%
# Group by Region and sum the revenue
region_revenue = df.groupby('Region')['Revenue'].sum()

# Identify highest and lowest
highest_region = region_revenue.idxmax()
lowest_region = region_revenue.idxmin()

print("Total Revenue by Region:")
print(region_revenue)
print(f"\nRegion with Highest Revenue: {highest_region} (${region_revenue[highest_region]:.2f})")
print(f"Region with Lowest Revenue: {lowest_region} (${region_revenue[lowest_region]:.2f})")

# %% [markdown]
# Q10. Extract the month from the Date column using Pandas and group the dataset by month to calculate the total monthly revenue. Also, calculate the mean, median, and standard deviation of the Revenue column using NumPy.

# %%
# Ensure the Date column is in datetime format to extract the month
df['Date'] = pd.to_datetime(df['Date'], format='mixed', dayfirst=True)

# Extract month and create a new column
df['Month'] = df['Date'].dt.month

# Group by Month to calculate total monthly revenue
monthly_revenue = df.groupby('Month')['Revenue'].sum()

print("Total Monthly Revenue:")
print(monthly_revenue)

# Calculate mean, median, and std dev using NumPy
revenue_mean = np.mean(df['Revenue'])
revenue_median = np.median(df['Revenue'])
revenue_std = np.std(df['Revenue'])

print("\nRevenue Statistics:")
print(f"Mean: ${revenue_mean:.2f}")
print(f"Median: ${revenue_median:.2f}")
print(f"Standard Deviation: ${revenue_std:.2f}")
# Out:
# Total Monthly Revenue:
# Month
# 1     50558.210526
# 2     33028.000000
# 3     10557.000000
# 4     57298.526316
# 5     27915.000000
# 6     37935.000000
# 7     47851.292159
# 8     76958.000000
# 9     30719.105263
# 10    42097.000000
# 11    32534.736842
# 12    44383.000000
# Name: Revenue, dtype: float64
#
# Revenue Statistics:
# Mean: $4918.35
# Median: $3466.50
# Standard Deviation: $4646.77
